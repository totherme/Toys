# %%
ls = "Mar 29 00:11:35 almaz sshd[11565]: Received disconnect from 115.230.127.55: 11:  [preauth]\n".split(" ")
ls
# Out:
# ['Mar',
#  '29',
#  '00:11:35',
#  'almaz',
#  'sshd[11565]:',
#  'Received',
#  'disconnect',
#  'from',
#  '115.230.127.55:',
#  '11:',
#  '',
#  '[preauth]\n']

# %%
class Event:
    def __init__(self, logline):
        self.date =

# %%
with open("log-emails") as f:
    for line in f:
        if (line.startswith("Date:")):
            print "date line"
            if(line.endswith("+0000\n")): print "We're in GMT"
            elif(line.endswith("+0100\n")): print "We're in BST"
            else: print "We're in some other timezone, and I am filled with terror"
        if (line=="=-=-=-=-=-=-=\n"):
            print "beginning of block"
        if (line=="\n"):
            print "possible end of block"
# Out:
# date line
# We're in GMT
# possible end of block
# possible end of block
# beginning of block
# possible end of block
# possible end of block
# date line
# We're in GMT
# possible end of block
# possible end of block
# beginning of block
# possible end of block
# possible end of block
# date line
# We're in GMT
# possible end of block
# possible end of block
# beginning of block
# possible end of block
# possible end of block
# date line
# We're in GMT
# possible end of block
# possible end of block
# beginning of block
# possible end of block
# possible end of block
# date line
# We're in GMT
# possible end of block
# possible end of block
# beginning of block
# possible end of block
# possible end of block
# date line
# We're in GMT
# possible end of block
# possible end of block
# beginning of block
# possible end of block
# possible end of block
# date line
# We're in GMT
# possible end of block
# possible end of block
# beginning of block
# possible end of block
# ...

# %%
dir("")
# Out:
# ['__add__',
#  '__class__',
#  '__contains__',
#  '__delattr__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__getnewargs__',
#  '__getslice__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__mod__',
#  '__mul__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__rmod__',
#  '__rmul__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '_formatter_field_name_split',
#  '_formatter_parser',
#  'capitalize',
#  'center',
#  'count',
#  'decode',
#  'encode',
#  'endswith',
#  'expandtabs',
#  'find',
#  'format',
#  'index',
#  'isalnum',
#  'isalpha',
#  'isdigit',
#  'islower',
#  'isspace',
#  'istitle',
#  'isupper',
#  'join',
#  'ljust',
#  'lower',
#  'lstrip',
#  'partition',
#  'replace',
#  'rfind',
#  'rindex',
#  'rjust',
#  'rpartition',
#  'rsplit',
#  'rstrip',
#  'split',
#  'splitlines',
#  'startswith',
# ...

# %%
print "fred"
# Out:
# fred

# %%
# Out:
# 0
